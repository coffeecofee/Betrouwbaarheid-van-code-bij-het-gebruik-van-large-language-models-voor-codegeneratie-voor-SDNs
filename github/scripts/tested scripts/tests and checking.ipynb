# %%
pip install python-Levenshtein
# Out:
# Collecting python-Levenshtein
#   Using cached python_Levenshtein-0.25.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting Levenshtein==0.25.1 (from python-Levenshtein)
#   Using cached Levenshtein-0.25.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Collecting rapidfuzz<4.0.0,>=3.8.0 (from Levenshtein==0.25.1->python-Levenshtein)
#   Downloading rapidfuzz-3.9.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Using cached python_Levenshtein-0.25.1-py3-none-any.whl (9.4 kB)
# Using cached Levenshtein-0.25.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (176 kB)
# Downloading rapidfuzz-3.9.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 8.4 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Installing collected packages: rapidfuzz, Levenshtein, python-Levenshtein
# Successfully installed Levenshtein-0.25.1 python-Levenshtein-0.25.1 rapidfuzz-3.9.4
# Note: you may need to restart the kernel to use updated packages.

# %%
code_snippets_first_prompt = [
    """
   import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
println("Data transfer completed successfully.");

    """,
    """
  import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));

    """,
    """
import commit_result;
import copy_result;

#[on("bob")]

bobs_jedis := "bobs_jedis";
jedis := "jedis";

commit_result(bobs_jedis, copy_result(new Data { name := jedis }));

println("Data transfer completed successfully.");

    """,
    """
   import commit_result;
import copy_result;

bobs_jedis := "bobs_jedis";
jedis := "jedis";

#[on("bob")]
commit_result(bobs_jedis, copy_result(new Data { name := jedis }));

    """,
    """
import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
println("Data transfer completed successfully.");

    """,
      """
   import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));

    """,
    """
  import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result( new Data { name := "jedis" } ));

    """,
    """
// Import the copy_result function
import copy_result;

// Define the variables
let bobs_jedis = "bobs_jedis";
let jedis = "jedis";
let bob = "Bob";

// Define the workflow on Bob's node
#[on("Bob")]
commit_result(bobs_jedis, copy_result(new Data { name := jedis }));

// Print a confirmation message
println("Data transfer completed from Amy to Bob.");

    """,
    """
   import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
println("Data transfer completed successfully.");

    """,
    """
import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
println("Data transfer completed successfully.");

    """,
      """
  import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
 
    """,
    """
 import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
println("Data transfer completed successfully.");
 
    """,
    """
import commit_result, copy_result;
#[on("bob")]
fn transfer_data() {
    commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
}
fn main() {
    transfer_data();
}

    """,
    """
   import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));

println("Data transfer completed successfully.");

    """,
    """
import copy_result from "path/to/copy_result";

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
println("Data transfer completed successfully.");

    """,
      """
 import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
println("Data transfer completed successfully.");
  
    """,
    """
  import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
println("Data transfer completed successfully.");

    """,
    """
import copy_result;  //[1]

#[on("bob")]  //[2]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
println("Data transfer completed successfully.");

    """,
    """
  import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));

println("Data transfer completed successfully.");
 
    """,
    """
import copy_result from 'path/to/copy_result';  // Importing copy_result function

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
println("Data transfer completed successfully.");

    """,
      """
 import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
println("Data transfer complete.");
  
    """,
    """
import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
println("Data transfer completed successfully.");
  
    """,
    """
import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
println("Data transfer completed successfully.");

    """,
    """
import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
println("Data transfer completed successfully.");

  
    """,
    """
import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
println("Data transfer completed successfully.");

    """,
  """
import commit_result, copy_result;

#[on("bob")]
dataset_name := "bobs_jedis";
new_name := "jedis";

commit_result(dataset_name, copy_result(new Data { name := new_name }));

println("Data transfer executed successfully.");
   
    """,
    """
import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
  
    """,
    """
import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));

    """,
    """
import copy_result;
import println;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
   
    """,
    """
import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));

    """
    
]

code_snippets_second_prompt = [
        """
   import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(
    new Data {
        name := "jedis"
    }
));

    """,
    """
  import copy_result;

commit_result("bobs_jedis", copy_result(
    new Data { name := "jedis" }
));

#[on("bob")]

    """,
    """
import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));

    """,
    """
 import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
  
    """,
    """
import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(
    new Data {
        name := "jedis"
    }
));

println("Workflow executed successfully.");

    """,
      """
import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
   
    """,
    """
import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
  
    """,
    """
import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));

    """,
    """
import copy_result; #[on("bob")]

commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));

println("Data transfer completed successfully.");
   
    """,
    """
import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(
    new Data { name := "jedis" }
));

    """,
      """
import copy_result;

commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));

#[on("bob")]
   
    """,
    """
import copy_result;
#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
  
    """,
    """
import copy_results;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));

    """,
    """
import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
   
    """,
    """
import copy_results;

commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));

#[on("bob")]

    """,
      """
import copy_result;

commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));

#[on("bob")]
   
    """,
    """
import copy_results;

#[on("Bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
  
    """,
    """
import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));

    """,
    """
import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result( new Data { name := "jedis" }));
   
    """,
    """
import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));

    """,
      """
import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
   
    """,
    """
import copy_result from "copy_results";
#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
  
    """,
    """
import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));

    """,
    """
import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
   
    """,
    """
import copy_result;

commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));

#[on("bob")]

    """,
  """
import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result( new Data { name := "jedis" }));
   
    """,
    """
import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(
    new Data {
        name := "jedis"
    }
));
  
    """,
    """
import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));

    """,
    """
import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
   
    """,
    """
import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(
    new Data { name := "jedis" }
));

    """
  
]

# %%
# csv basic prompt

# %%
import re
import csv
import Levenshtein

# Define preprocess_code function to return preprocessed code
def preprocess_code(code):
    # Remove comments starting with //
    code_without_comments = re.sub(r'//.*?\n', '\n', code)  # Remove // comments
    
    # Normalize whitespace
    code_normalized = re.sub(r'\s+', ' ', code_without_comments)
    
    return code_normalized.strip()


# Define a separate reference snippet
reference_snippet = """
import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
"""

# Preprocess all code snippets
preprocessed_snippets = [preprocess_code(code) for code in code_snippets_first_prompt]

# Preprocess the reference snippet
preprocessed_reference = preprocess_code(reference_snippet)

# Calculate edit distances against the reference snippet
distances = [Levenshtein.distance(preprocessed_reference, snippet) for snippet in preprocessed_snippets]

# Calculate average edit distance
average_distance = sum(distances) / len(distances) if distances else 0

# Find the highest edit distance
max_distance = max(distances) if distances else 0

print("Average Edit Distance (against reference snippet):", average_distance)
print("Highest Edit Distance (against reference snippet):", max_distance)

# Prepare data for CSV
rows = [("Snippet", "Original Code", "Edit Distance")]
for i, snippet in enumerate(preprocessed_snippets):
    rows.append((i+1, code_snippets_first_prompt[i], distances[i]))

# Write to CSV file
csv_filename = "edit_distances_basic_prompt_testing.csv"
with open(csv_filename, mode='w', newline='') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerows(rows)

print(f"CSV file '{csv_filename}' has been successfully generated with edit distances.")
# Out:
# Average Edit Distance (against reference snippet): 47.7
# Highest Edit Distance (against reference snippet): 133
# CSV file 'edit_distances_basic_prompt_testing.csv' has been successfully generated with edit distances.

# %%
import re
import csv
import Levenshtein

# Define preprocess_code function to return preprocessed code and original snippet
def preprocess_code(code):
    # Remove comments
    code_without_comments = re.sub(r'#.*', '', code)
    # Normalize whitespace
    code_normalized = re.sub(r'\s+', ' ', code_without_comments)
    return code_normalized.strip(), code.strip()


# Define a separate reference snippet
reference_snippet = """
import copy_result;



#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
    """

# Preprocess all code snippets
preprocessed_snippets = [preprocess_code(code) for code in code_snippets_second_prompt ]

# Preprocess the reference snippet
preprocessed_reference, original_reference = preprocess_code(reference_snippet)

# Calculate edit distances against the reference snippet
distances = [Levenshtein.distance(preprocessed_reference, snippet[0]) for snippet in preprocessed_snippets]

# Calculate average edit distance
average_distance = sum(distances) / len(distances) if distances else 0

# Find the highest edit distance
max_distance = max(distances) if distances else 0

print("Average Edit Distance (against reference snippet):", average_distance)
print("Highest Edit Distance (against reference snippet):", max_distance)

# Prepare data for CSV
rows = [("Snippet", "Original Code", "Edit Distance")]
for i, snippet in enumerate(preprocessed_snippets):
    rows.append((i+1, snippet[1], distances[i]))

# Write to CSV file
csv_filename = "edit_distances_final_prompt_testing.csv"
with open(csv_filename, mode='w', newline='') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerows(rows)

print(f"CSV file '{csv_filename}' has been successfully generated with edit distances.")
# Out:
# Average Edit Distance (against reference snippet): 4.366666666666666
# Highest Edit Distance (against reference snippet): 50
# CSV file 'edit_distances_final_prompt_testing.csv' has been successfully generated with edit distances.

# %%
# LED TEST 2

# %%
import re
import Levenshtein

# Define preprocess_code function to remove // comments and normalize whitespace
def preprocess_code(code):
    code_without_comments = re.sub(r'//.*?\n', '\n', code)  # Remove // comments
    code_normalized = re.sub(r'\s+', ' ', code_without_comments)  # Normalize whitespace
    return code_normalized.strip()

# Define function to calculate Levenshtein distance between two preprocessed code snippets
def calculate_led(snippet1, snippet2):
    return Levenshtein.distance(snippet1, snippet2)

# Example usage
if __name__ == "__main__":
    # Define reference snippet and test snippet
    reference_snippet = """
import copy_result;



#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
    """

    test_snippet = """import commit_result, copy_result;

#[on("bob")]
dataset_name := "bobs_jedis";
new_name := "jedis";

commit_result(dataset_name, copy_result(new Data { name := new_name }));

println("Data transfer executed successfully.");"""

    # Preprocess snippets
    preprocessed_reference = preprocess_code(reference_snippet)
    preprocessed_test = preprocess_code(test_snippet)

    # Calculate LED
    led_value = calculate_led(preprocessed_reference, preprocessed_test)

    # Print results
    print("Preprocessed Reference Snippet:", preprocessed_reference)
    print("Preprocessed Test Snippet:", preprocessed_test)
    print("Levenshtein Edit Distance:", led_value)
# Out:
# Preprocessed Reference Snippet: import copy_result; #[on("bob")] commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
# Preprocessed Test Snippet: import commit_result, copy_result; #[on("bob")] dataset_name := "bobs_jedis"; new_name := "jedis"; commit_result(dataset_name, copy_result(new Data { name := new_name })); println("Data transfer executed successfully.");
# Levenshtein Edit Distance: 133

# %%
# LED TESTS 1, Code voor steek proef gewijs door de LED te gaan om te checken of deze correct zijn berekend

import re
import Levenshtein

# Function to preprocess code by removing comments and normalizing whitespace
def preprocess_code(code):
    code_without_comments = re.sub(r'#.*', '', code)  # Remove comments
    code_normalized = re.sub(r'\s+', ' ', code_without_comments)  # Normalize whitespace
    return code_normalized.strip(), code.strip()

# Function to calculate LED between two preprocessed code snippets
def calculate_led(snippet1, snippet2):
    return Levenshtein.distance(snippet1, snippet2)

# Reference snippet
reference_snippet = """
import copy_result;



#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
    """

# Test snippet to preprocess and compare

# code snippet 1.1
test_snippet =  """
   import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
println("Data transfer completed successfully.");

    """

# code snippet 1.15
test_snippet2 = """
import copy_result from "path/to/copy_result";

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
println("Data transfer completed successfully.");

    """

test_snippet3 =   """
  import copy_result;

#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));

    """


# Preprocess both snippets
preprocessed_reference, _ = preprocess_code(reference_snippet)
preprocessed_test, _ = preprocess_code(test_snippet3)

# Calculate LED
led_value = calculate_led(preprocessed_reference, preprocessed_test)

# Print the result
print("Preprocessed Reference Snippet:", preprocessed_reference)
print("Preprocessed Test Snippet:", preprocessed_test)
print("Levenshtein Edit Distance:", led_value)

# LED hoort 50 te zijn voor codefragment 1.1

# LED hoort 77 te zijn voor codefragment 1.15

# LED hoort 0 te zijn voor codefragment 1.2
# Out:
# Preprocessed Reference Snippet: import copy_result; commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
# Preprocessed Test Snippet: import copy_result; commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
# Levenshtein Edit Distance: 0

# %%
print(len(' println("Data transfer completed successfully.");'))
# Out:
# 50

# %%
print(len('from "path/to/copy_result"; println("Data transfer completed successfully.");'))
# Out:
# 77

# %%
# zover ik kan zien is de manier waarop LED berekent in dit onderzoek correct

# %%
# LCS FIRST PROMPT

# %%
import csv

def remove_comments_and_whitespace(code):
    # Remove comments (assuming comments are in /* ... */ or // ... format)
    import re
    code = re.sub(r'/\*.*?\*/', '', code, flags=re.DOTALL)  # Remove /* ... */
    code = re.sub(r'//.*?\n', '\n', code)  # Remove // ...
    
    # Normalize whitespace
    code = re.sub(r'\s+', ' ', code)  # Replace multiple spaces with a single space
    
    # Remove leading/trailing whitespace
    code = code.strip()
    
    return code

def longest_common_subsequence(X, Y):
    m = len(X)
    n = len(Y)
    
    # Create a table to store lengths of longest common subsequence.
    dp = [[0] * (n + 1) for _ in range(m + 1)]
    
    # Building the dp array in bottom-up fashion
    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if X[i - 1] == Y[j - 1]:
                dp[i][j] = dp[i - 1][j - 1] + 1
            else:
                dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])
    
    # dp[m][n] contains the length of LCS for X[0..m-1], Y[0..n-1]
    return dp[m][n]

# %%
def calculate_lcs_with_reference_first(code_snippets, reference_code):
    # Preprocess the reference code and each code snippet to remove comments and normalize whitespace
    reference_code = remove_comments_and_whitespace(reference_code)
    processed_snippets = [remove_comments_and_whitespace(code) for code in code_snippets]
    
    num_snippets = len(processed_snippets)
    
    if num_snippets == 0:
        print("No snippets to compare.")
        return
    
    # Initialize variables for lowest LCS length and total LCS length for average calculation
    lowest_lcs_length = float('inf')
    total_lcs_length = 0
    
    lcs_values = []
    
    # Calculate LCS with the reference code
    for snippet in processed_snippets:
        lcs_length = longest_common_subsequence(reference_code, snippet)
        lcs_values.append(lcs_length)
        total_lcs_length += lcs_length
        if lcs_length < lowest_lcs_length:
            lowest_lcs_length = lcs_length
    
    # Calculate average LCS length
    average_lcs_length = total_lcs_length / num_snippets
    
    # Write the LCS values to a CSV file
    with open('lcs_values_beginprompt_testing.csv', 'w', newline='') as csvfile:
        csvwriter = csv.writer(csvfile)
        csvwriter.writerow(['Snippet Index', 'LCS Length'])
        for index, lcs_length in enumerate(lcs_values):
            csvwriter.writerow([index, lcs_length])
    
    return lowest_lcs_length, average_lcs_length

def calculate_lcs_with_reference_last(code_snippets, reference_code):
    # Preprocess the reference code and each code snippet to remove comments and normalize whitespace
    reference_code = remove_comments_and_whitespace(reference_code)
    processed_snippets = [remove_comments_and_whitespace(code) for code in code_snippets]
    
    num_snippets = len(processed_snippets)
    
    if num_snippets == 0:
        print("No snippets to compare.")
        return
    
    # Initialize variables for lowest LCS length and total LCS length for average calculation
    lowest_lcs_length = float('inf')
    total_lcs_length = 0
    
    lcs_values = []
    
    # Calculate LCS with the reference code
    for snippet in processed_snippets:
        lcs_length = longest_common_subsequence(reference_code, snippet)
        lcs_values.append(lcs_length)
        total_lcs_length += lcs_length
        if lcs_length < lowest_lcs_length:
            lowest_lcs_length = lcs_length
    
    # Calculate average LCS length
    average_lcs_length = total_lcs_length / num_snippets
    
    # Write the LCS values to a CSV file
    with open('lcs_values_eindprompt_testing.csv', 'w', newline='') as csvfile:
        csvwriter = csv.writer(csvfile)
        csvwriter.writerow(['Snippet Index', 'LCS Length'])
        for index, lcs_length in enumerate(lcs_values):
            csvwriter.writerow([index, lcs_length])
    
    return lowest_lcs_length, average_lcs_length

reference_code = """
import copy_result;



#[on("bob")]
commit_result("bobs_jedis", copy_result(new Data { name := "jedis" }));
"""

# %%
lowest_lcs, average_lcs = calculate_lcs_with_reference_first(code_snippets_first_prompt, reference_code)

print(f"Lowest LCS length: {lowest_lcs}")
print(f"Average LCS length: {average_lcs}")
# Out:
# Lowest LCS length: 90
# Average LCS length: 103.1

# %%
lowest_lcs, average_lcs = calculate_lcs_with_reference_last(code_snippets_second_prompt, reference_code)

print(f"Lowest LCS length: {lowest_lcs}")
print(f"Average LCS length: {average_lcs}")
# Out:
# Lowest LCS length: 91
# Average LCS length: 101.8

# %%
def remove_comments_and_whitespace(code):
    # Remove comments (assuming comments are in /* ... */ or // ... format)
    import re
    code = re.sub(r'/\*.*?\*/', '', code, flags=re.DOTALL)  # Remove /* ... */
    code = re.sub(r'//.*?\n', '\n', code)  # Remove // ...
    
    # Normalize whitespace
    code = re.sub(r'\s+', ' ', code)  # Replace multiple spaces with a single space
    
    # Remove leading/trailing whitespace
    code = code.strip()
    
    return code


import re
import Levenshtein

# Function to preprocess code by removing comments and normalizing whitespace
def preprocess_code(code):
    code_without_comments = re.sub(r'#.*', '', code)  # Remove comments
    code_normalized = re.sub(r'\s+', ' ', code_without_comments)  # Normalize whitespace
    return code_normalized.strip(), code.strip()
